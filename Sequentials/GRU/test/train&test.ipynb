# %%
import matplotlib.pyplot as plt 
import numpy as np 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cda43f53-6a95-483e-8405-0cbbe9fe2d44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cda43f53-6a95-483e-8405-0cbbe9fe2d44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model.py to model.py

# %%
input_20 = np.load('inputs20:21.npy', allow_pickle=True)
y_20 = np.load('outputs20:21.npy', allow_pickle=True)
input_19 = np.load('inputs19:20.npy', allow_pickle=True)
y_19 = np.load('outputs19:20.npy', allow_pickle=True)

# %%
INPUTS = np.vstack((input_20,input_19))
LABELS = np.vstack((y_20,y_19))
train_X, test_X, train_y, test_y = train_test_split(INPUTS, LABELS, test_size = 0.3, shuffle = True)

# %%
from model import Model


units = [256,512]
batches = [16,32,64]
drates = [.2,.3,.4,.5]
epochs = [125,150,175]
# BEST PICK units = 256, learing rate = 2e-4, batch = 16, drate = 0.2 

# TESTS ON 256 units
for epoch in epochs:
  m2e = Model(train_X, train_y, lr = 2e-4, units = 256, drate = .2)
  m2e.train(epochs = epoch, batch = 16)
  m2e.plot()
  m2e.accuracy(test_X, test_y)
# Out:
# Test loss: 0.28364184498786926 Test accuracy: 0.89
# Test loss: 0.2916482388973236 Test accuracy: 0.89
# Test loss: 0.34802237153053284 Test accuracy: 0.89

# %%
# TESTS ON 512

batches = [16,32,64]
drates = [.2,.3,.4,.5]
epochs = [75,100,125]
# BEST PICK units = 512, learing rate = 1e-4, batch = 16, drate = 0.2 



m2e = Model(train_X, train_y, lr = 1e-4, units = 512, drate = .2)
m2e.train(epochs = 70, batch = 16)
m2e.plot()
m2e.accuracy(test_X, test_y)
# Out:
# Test loss: 0.22120410203933716 Test accuracy: 0.91

# %%
m2e.plot(save = True)

# %%
m2e.GRU.save_weights('weights92acc.h5')
files.download('weights92acc.h5')
